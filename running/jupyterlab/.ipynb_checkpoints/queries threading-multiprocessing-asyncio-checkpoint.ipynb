# %%
# !python ../../code/quantityer.py -i ../queries/ -o -e github **user 626b86cd521ee06111476281b98c9aae488c18cc **waiting-factor 7 -c shelf ../report-cache-1 --log-files debug ../debug-1.log
# Out:
# --------------------------------------------------------------------
#     Results for query 1 from <../queries/1 - query-asyncio.in>
#
#         Results quantity: 69648
#
#         Sub-queries total: 15
#             Issued:          15 (100% of total)
#
#         Server begin datetime: 2019-11-23 17:32:17
#         Server end datetime:   2019-11-23 17:36:08
#
#         Runtime:                           0:03:51
#         Estimated runtime with caching:    from 0:00:30 to 0:03:30
#         Estimated runtime without caching: from 0:00:30 to 0:03:30
#
#
#     The processed query was:
#
# [
#     @asyncio [
#         asyncio
#         {
#             @semaphores [
#                 {Lock Semaphore}
#                 @aq_rel[acquire release]
#             ]
#             @event      [Event set wait clear]
#             @condition  [Condition wait notify]
#         }
#     ]
#     language:Python
#     fork:true
# ]
#
#
#     Longest subquery:
#
# ...

# %%
# !python ../../code/quantityer.py -i ../queries/asyncio-multiprocessing-threading.input -o -e github **user 626b86cd521ee06111476281b98c9aae488c18cc **waiting-factor 7 -c shelf ../report-cache-2 --log-files debug ../debug-2.log
# Out:
# --------------------------------------------------------------------
#     Results for query 1 from <../queries/asyncio-multiprocessing-threading.input>
#
#         Results quantity: 1530299
#
#         Sub-queries total: 8191
#             From cache:      8025 (97.9734% of total)
#             Issued:          166 (2.02661% of total)
#
#         Server begin datetime: 2019-11-23 18:15:22
#         Server end datetime:   2019-11-23 18:50:10
#
#         Runtime:                           0:34:48
#         Estimated runtime with caching:    from 0:05:32 to 0:38:44
#         Estimated runtime without caching: from 4:33:02 to 1 day, 7:51:14
#
#
#     The processed query was:
#
# [
#     {
#         [
#             asyncio
#             {
#                 @semaphores [{Lock Semaphore} [acquire release]]
#                 @event      [Event set wait clear]
#                 @condition  [Condition wait notify]
#             }
#         ]
#         [
#             multiprocessing
# ...
